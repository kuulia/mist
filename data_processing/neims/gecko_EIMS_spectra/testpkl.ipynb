# %%
import pickle as pkl
from numpy import __version__ as numpyver
from pandas import __version__ as pandasver
print(numpyver, pandasver)

# %%
with open('df_neims_gecko.pkl', 'rb') as file:
    data = pkl.load(file)
data
# Out:
#                                                    SMILES  \
# 0                                                   C(=O)
# 1                                        C(=O)(N(=O)(=O))
# 2                                   C(=O)(N(=O)(=O))C(=O)
# 3                                C(=O)(N(=O)(=O))C(=O)(O)
# 4                               C(=O)(N(=O)(=O))C(=O)(OO)
# ...                                                   ...
# 166429  CC1(O)C(O)(C(=O)(OON(=O)(=O)))OOC1C(O)C(=O)(OO...
# 166430        CC1(O)C(O)(C(=O)(OON(=O)(=O)))OOC1C(O)C(=O)
# 166431       CC1(O)C(O)(C(=O)(OON(=O)(=O)))OOC1C(=O)C(=O)
# 166432  CC1(O)C(O)(C(=O)(OON(=O)(=O)))OOC1C(=O)(OON(=O...
# 166433                CC1(O)C(O)(C(=O)(OO))OOC1C(OO)C(=O)
#
#                                                      spec
# 0       [[14, 15, 16, 18, 19, 25, 26, 27, 28, 29, 30, ...
# 1       [[14, 16, 17, 18, 19, 27, 28, 29, 30, 31, 32, ...
# 2       [[14, 15, 16, 17, 18, 19, 25, 27, 28, 29, 30, ...
# ...

# %%
with open('df_neims_gecko_TMS.pkl', 'rb') as file:
    data = pkl.load(file)
data
